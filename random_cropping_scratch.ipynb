# %%
from anotherJEPA3 import TrajectoryDataset, flip_augmentation, shift_augmentation, random_cropping_augmentation
import random
import torch
import PIL
import matplotlib.pyplot as plt

# %%
dataset = TrajectoryDataset('../data/states.npy', '../data/actions.npy', augmentations=random_cropping)
states, actions = dataset[8]  # This will print "augmenting"

start = states[0][0]  # Example indexing to get the tensor
end = states[-1][0]
walls = states[0][1]

plt.imshow(start+end+walls)

# %%
augmentations = [flip_augmentation, shift_augmentation, random_cropping_augmentation]
dataset = TrajectoryDataset('../data/states.npy', '../data/actions.npy')
states, actions = dataset[10]  # This will print "augmenting"

start = states[0][0]  # Example indexing to get the tensor
end = states[-1][0]
walls = states[0][1]

plt.imshow(start+end+walls)

# %%
augmentations = [flip_augmentation, shift_augmentation, random_cropping_augmentation]
dataset = TrajectoryDataset('../data/states.npy', '../data/actions.npy', augmentations=augmentations)
states, actions = dataset[10]  # This will print "augmenting"

start = states[0][0]  # Example indexing to get the tensor
end = states[-1][0]
walls = states[0][1]

plt.imshow(start+end+walls)

# %%
augmentations = [flip_augmentation, shift_augmentation, random_cropping_augmentation]
dataset = TrajectoryDataset('../data/states.npy', '../data/actions.npy')
states, actions = dataset[8]  # This will print "augmenting"

start = states[0][0]  # Example indexing to get the tensor
end = states[-1][0]
walls = states[0][1]

plt.imshow(start+end+walls)

# %%
augmentations = [shift_augmentation]
dataset = TrajectoryDataset('../data/states.npy', '../data/actions.npy', augmentations=augmentations)
states, actions = dataset[8]  # This will print "augmenting"

start = states[0][0]  # Example indexing to get the tensor
end = states[-1][0]
walls = states[0][1]

plt.imshow(start+end+walls)
